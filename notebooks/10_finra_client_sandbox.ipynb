# %%
import pandas as pd

from services.market import FINRA

# %%
client = FINRA()

# %%
await client.refresh_session()

# %%
client.get_short_sale_volume("LQD", limit=5)

# %%
client.get_treasury_monthly_aggregates(limit=5)

# %%
CUSIP = "30303MAD4"
TRADE_DATE = "2026-04-28"

# %%
details = await client.get_bond_details(CUSIP)
pd.Series(details)

# %%
await client.get_price_yield(CUSIP, TRADE_DATE)

# %%
symbol = details.get("issueSymbolIdentifier")
symbol

# %%
ticks = await client.get_trade_history(symbol, TRADE_DATE, limit=100) if symbol else pd.DataFrame()
ticks.head()

# %%
bond = await client.get_bond_analytics(CUSIP, TRADE_DATE)
pd.Series(bond.__dict__)
